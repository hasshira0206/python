# %% [markdown]
# <a href="https://colab.research.google.com/github/hasshira0206/python/blob/main/%E3%81%82%E3%82%89%E3%82%86%E3%82%8B%E8%87%AA%E7%84%B6%E6%95%B0%E3%82%922%E3%81%A4%E3%81%AE%E7%B4%A0%E6%95%B0%E3%81%AE%E5%92%8C%E3%81%A7%E8%A1%A8%E3%81%99.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n=int(input("＞自然数を入力："))
if n<4:
  print("＞無理ですよw")
n1=n
n2=n
n//=2
y=0
a=0
while y<n:
  y+=1
  x=n1-y
  flag=True #Trueなら素数である
  for i in range(2,y):
    if y%i==0:
      flag=False #素数である
      break
  if flag==True:
    flag=True #Trueなら素数である
    for i in range(2,x):
      if x%i==0:
        flag=False #素数である
        a+=1
        break
  if x!=1:
    if y!=1:
      if flag==True:
        print("""
--【{}】------------------------
＞結果は【{}】＋【{}】です。
-------------------------------
""".format(n2,x,y))
# Out:
# ＞自然数を入力：6216
#
# --【6216】------------------------
# ＞結果は【6211】＋【5】です。
# -------------------------------
#
#
# --【6216】------------------------
# ＞結果は【6203】＋【13】です。
# -------------------------------
#
#
# --【6216】------------------------
# ＞結果は【6199】＋【17】です。
# -------------------------------
#
#
# --【6216】------------------------
# ＞結果は【6197】＋【19】です。
# -------------------------------
#
#
# --【6216】------------------------
# ＞結果は【6173】＋【43】です。
# -------------------------------
#
#
# --【6216】------------------------
# ＞結果は【6163】＋【53】です。
# -------------------------------
#
#
# --【6216】------------------------
# ＞結果は【6143】＋【73】です。
# -------------------------------
#
#
# --【6216】------------------------
# ＞結果は【6133】＋【83】です。
# -------------------------------
#
#
# --【6216】------------------------
# ＞結果は【6113】＋【103】です。
# -------------------------------
#
#
# --【6216】------------------------
# ＞結果は【6089】＋【127】です。
# -------------------------------
#
#
# --【6216】------------------------
# ...
